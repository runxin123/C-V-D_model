# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# config = {
#     "font.family":'Times New Roman',
#     "font.size": 20,
#     "font.weight":'bold'
# }
# rcParams.update(config)
# font1 = {'family' : 'Times New Roman',
# 'weight' : 'normal',
# 'size'   : 30}
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# %%
L2MO4_Ea=[346.8,
396.9,
411.2,
447.4,
367.7,
336.7,
324.3,
285]

L2MO4_ci=[
0.005291,
0.002308,
0.004327,
0.003157,
0.004912,
0.001427,
0.004356,
0.007392
]
L2MO4_ct = [0.0027961518911311,0.0052211349289465,0.1093728842011542,0.2833390804889976,0.119493171189275,0.0290248181689941,0.003016,0.007314]

L2MO4_cs=[1.167489,
1.1853954,
1.14892,
1.032465,
0.919092,
0.974462,
0.867259,
1.009178]

L2MO4_co = [1.165476,1.299428,1.348901,1.9788606449385575,2.325178,1.836796,2.387692067030657,2.399340660631557]

# fi=[9.126552,
# 11.2693545,
# 12.19011,
# 12.588189,
# 13.2772335,
# 13.8004175,
# 13.5315905,
# 13.027793]



L2MO4_volt=[4.9,
4.24,
3.96,
3.95,
3.84,
3.7,
3.76,
3.870
]


L2MO4_volo=[16.314,
14.24,
13.62,
13.51,
12.889,
12.5469,
12.6,
11.7052]

L2MO4_v=[705.7396298,
607.3109786,
569.5848266,
568.6579944,
546.3857288,
527.7375115,
523.1977234,
534.485469]

L2MO4_a = [1.28,1.2951875,1.1963375,1.13734,1.10475,1.052,0.923,0.84]
L2MO4_v = [i/32 for i in L2MO4_v]

# %%
lmx_v  = {'X=Br':[25.39,29.47,33.67],'X=Cl':[20.9,24.59,28.33],'X=I':[32.83,37.56,42.41]}
lmx_Ea  = {'X=Br':[0.5189,0.4433,0.2267],'X=Cl':[0.424,0.154,0.3433],'X=I':[0.4561,0.383,0.355]}
lmx_ct = {'X=Br':[2.388665,1.960327,0.268938],'X=Cl':[1.10,0.27,0.377],'X=I':[3.894374249,3.608,2.269044]}
lmx_vt  = {'X=Br':[7.457829029,8.718242896,9.421883459],'X=Cl':[5.82226,6.79558,7.58677],'X=I':[9.56844592
,10.18852444,13.75340042]}
lmx_vo = {'X=Br':[28.27,29.35,30.43],'X=Cl':[23.21,24.31,24.62],'X=I':[36.62,37.92,38.94]}
# lmx_FV = {'X=Br':[33.42,33.47,35.48],'X=Cl':[27.12,28.39,27.61],'X=I':[43.05,44.03,44.28]}
lmx_co = {'X=Br':[0.336260,0.394301,1.29684],'X=Cl':[0.485521,0.855015,1.231990],'X=I':[0.1993,0.30468,0.409702]}
lmx_a = {'X=Cl':[0.73576042,0.76522083,0.82701667],'X=Br':[0.75683125,0.74604375
,0.89284375],'X=I':[0.70519375
,0.7229375
,0.78533542]}
# for j in lmx_Ea:
#     for t in j:
#         c = j

LMO_Ea=[
343.5,
489.1,
543.5,
586.6,
603.9,
641.1,
662.8,
680]

LMS_Ea=[
488.7,
316.8,
269.9,
180,
69.3,
53.2
]
LMS_a = [
1.3160054719562244
,1.2202462380300956
,1.1190150478796168
,1.0205198358413132
,0.8235294117647058
,0.752393980848153
]
LMS_ci= [0.018956,
0.146906,
0.207527,
0.559368,
1.224235,
1.346276
]
LMS_cs=[
1.428,
1.891,
1.982,
2.273,
2.904,
3.169]
LMS_v = [
371.875,
344.0125,
331.95147,
323.725,
292.325,
297.918375
]
LMS_voli=[
7.8663,
7.7725,
7.733,
7.6937,
7.6749,
7.6197
]


LMS_vols=[
31.8962,
31.3438,
31.1828,
30.7726,
30.5792,
29.934
]


LMO_voli=[13.9816,
13.3,
13.01,
12.803,
12.620,
12.4,
12.29,
12.17
]

LMO_vols = [
3.9461,
3.87,
3.82,
3.809,
3.7241,
3.71,
3.7,
3.61
]

LMO_ci=[
0.387,
0.687,
0.722,
0.865,
0.869,
0.932,
1.051,
1.131]
LMO_cs=[
1.252845,
1.610225,
1.7512,
1.83028,
1.863878,
1.831,
1.924,
1.904135
]
LMO_a = [
    1.237991667,
    1.300491667,
    1.235875,
    1.178941667,
    1.153441667,
    1.109683333,
    1.049833333,
    1.047875
]


LMO_v=[240.208825,
218.577975,
209.3318,
207.975,
205.0683,
200.375875,
199.10115,
197.876125]

PLMS_co = [1.144831,0.952658,1.016334,0.912426,0.903831] 
PLMS_ct = [4.725657,3.475794,4.283016,3.732423,2.806455]
elements = ['Co','Cr','Fe','Ti','V']
PLMS_v = [115.257340/4,30.549020,115.64957/4,31.369534,126.961695/4]
ea = [0.298800,0.145000,0.167500,0.176200,0.025900]
PLMS_Ea = [i*1000 for i in ea]
PLMS_volo = [21.6712,22.0975,21.7474,22.1233,22.2524]
PLMS_volt =[6.3614,6.5786,6.3242,6.5535,6.8539]
m_v = [15.4833,18.8320,16.0939,20.1575,19.4468]
PLMS_a = [0.747,1.036,0.846,1.090,1.116]

LMO_v1 = [i/12 for i in LMO_v]
LMS_v1 = [i/8 for i in LMS_v]
LMO_symbol = ['O' for i in range(0,len(LMO_v1))]
LMS_symbol = ['S' for i in range(0,len(LMS_v1))]
PLMS_symbol = ['S' for i in range(0,len(PLMS_v))]
L2MO4_symbol = ['O' for i in range(0,len(L2MO4_v))]

LMO_sym = ['O-T' for i in range(0,len(LMO_v1))]
LMS_sym = ['T-O' for i in range(0,len(LMS_v1))]
PLMS_sym = ['O-T' for i in range(0,len(PLMS_v))]
L2MO4_sym = ['T-O' for i in range(0,len(L2MO4_v))]


lmx_ea = lmx_Ea['X=Cl']+lmx_Ea['X=Br']+lmx_Ea['X=I']
lmx_et = [i*1000 for i in lmx_ea]
ct = LMS_ci+PLMS_ct +LMO_cs 
# +PLMS_ct
# +L2MO4_ct
# PLMS_ct
# L2MO4_ct
# +lmx_ct['X=Cl']+lmx_ct['X=Br']+lmx_ct['X=I']
v = LMS_v1 +PLMS_v +LMO_v1 
# +PLMS_v
# +L2MO4_v
# PLMS_v
# +L2MO4_v
# +lmx_v['X=Cl']+lmx_v['X=Br']+lmx_v['X=I']
volt = LMS_voli +PLMS_volt +LMO_vols
# +PLMS_volt
# +L2MO4_volt
# PLMS_volt
# +L2MO4_volt
# + lmx_vt['X=Cl']+lmx_vt['X=Br']+lmx_vt['X=I']
volo = LMS_vols +PLMS_volo+LMO_voli
# +PLMS_volo
# +L2MO4_volo
# PLMS_volo
# +L2MO4_volo
# + lmx_vo['X=Cl']+lmx_vo['X=Br']+lmx_vo['X=I']
co = LMS_cs+PLMS_co +LMO_ci
# +PLMS_co
# + L2MO4_co
# PLMS_co
# + L2MO4_co
# + lmx_co['X=Cl']+lmx_co['X=Br']+lmx_co['X=I']
# cs = LMO_ci+LMS_cs
LMS_Ea1 = [i for i in LMS_Ea]
L2MO4_Ea1 = [i for i in L2MO4_Ea]
LMO_Ea1 = [-i for i in LMO_Ea]
PLMS_Ea1 = [-i for i in PLMS_Ea]
# lmx_et1 = [-i for i in lmx_et]
Ea = LMS_Ea1 +PLMS_Ea1+ LMO_Ea1
# + PLMS_Ea1
# +L2MO4_Ea1
# PLMS_Ea1
# +L2MO4_Ea1
# + lmx_et
LMO_a1 = [-i for i in LMO_a]
PLMS_a1 = [-i for i in PLMS_a]
a = LMS_a+PLMS_a1+ LMO_a1
# +PLMS_a1
# +L2MO4_a
# PLMS_a
# +L2MO4_a
sym = LMS_symbol+ PLMS_symbol+LMO_symbol
# + PLMS_symbol
# +L2MO4_symbol
# PLMS_symbol
# +L2MO4_symbol
msym = LMS_sym+PLMS_sym +LMO_sym
# +PLMS_sym
# +L2MO4_sym
# PLMS_sym
# +L2MO4_sym
# + lmx_a['X=Cl']+lmx_a['X=Br']+lmx_a['X=I']
print(len(ct))
# Out:
# 19

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import pandas as pd
config = {
    "font.family":'serif',
    "font.size": 20,
    "mathtext.fontset":'stix',
    "font.serif": ['Times New Roman'],
    "font.weight":'bold'
}
rcParams.update(config)
font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 40}

# %%
csm_o = LMO_cs
csm_t = LMO_ci
elements = ['Sc','Ti','V','Cr','Mn','Fe','Co','Ni']
volume = LMO_v1
# ea = 
ea = LMO_Ea
vol_o = LMO_voli
vol_t = LMO_vols
# m_v = [15.4833,18.8320,16.0939,20.1575,19.4468]
a_c = LMO_a
df = pd.DataFrame({'elem':elements,'volume':volume,'Ea':ea,'csm_o':csm_o,'csm_t':csm_t,'vol_o':vol_o,'vol_t':vol_t,'a_c':a_c})

# %%
# font1 = {'family' : 'Times New Roman',
# 'weight' : 'normal',
# 'size'   : 40}
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(33,10),dpi=300)
# plt.tight_layout()  
tit = 'X=I'
MX6 = 'MS_4'
element = 'Li'
element2 = 'P'
bader_chg_list = [0.72848437,0.9622875,1.2816375,1.58618438]
Li_X6 = {'Cl':22.80,'Br':27.9328,'I':36.4646,'P':4.37,'Li':7.8035}
Li_S = {'P','S','P3S11'}
x1 = 250
y1 = 750
marker_list =  ['o', 'p', '^', '<','p','s','d']
# ax = fig.add_subplot(111)
# ax.set_xlim((4,8))
# ax.set_ylim((24,30))
# # ax.set_tick_params(labelsize=23)
# ax.set_xlabel(r'$(XS_4)$Volume($A^3$)',font1)
# ax.set_ylabel(r'Transition Volume($A^3$)',font1)
ax = fig.add_subplot(132)
fig.subplots_adjust(wspace =0.5, hspace =0.2)
ax.set_xlim((x1,y1))
ax.set_ylim((10,15))
# ax.set_tick_params(labelsize=23)
ax.set_xlabel(r'$E_a$ (meV)',font1)
ax.set_ylabel('Volume of octahedral sites ($\AA^3$)',font1)

# ax.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax.set_xticklabels(fontname = 'Times New Roman', size = 23)
# plt.plot(X,Y,label='Relationship plot',linewidth=3.0)
ax.yaxis.label.set_color('black')
a1, = ax.plot(df['Ea'],df['vol_o'],marker_list[0],markersize=15,color='k',linewidth=4,label = "V-transition state volume")

ax2 = ax.twinx()

ax2.set_xlim((x1,y1))
ax2.set_ylim((3,4))
# ax2.set_tick_params(labelsize=23)
ax2.set_xlabel(r'$E_a$ (meV)',font1)
ax2.set_ylabel(r'Volume of tetrahedral sites ($\AA^3$)',font1)

ax2.tick_params(axis='x', labelsize= 30)
a2, = ax2.plot(df['Ea'],df['vol_t'], marker_list[0],markersize=15,color='b', linewidth=4,label='V-CSM')

'''setting the axis color'''
ax2.spines['right'].set_color('blue')
ax2.yaxis.label.set_color('blue')
ax2.tick_params(axis='y', colors='blue')



ax3 = fig.add_subplot(131)
ax3.set_xlim((x1,y1))
ax3.set_ylim((15,25))
# ax.set_tick_params(labelsize=23)
ax3.set_xlabel(r'$E_a$ (meV)',font1)
ax3.set_ylabel('Anion sublattice volume ($\AA^3$)',font1)

# plt.plot(X,Y,label='Relationship plot',linewidth=3.0)
ax3.yaxis.label.set_color('black')
ax3.spines['left'].set_color('black')
ax3.yaxis.label.set_color('black')
ax3.tick_params(axis='y', colors='black',labelsize=20)
a3, = ax3.plot(df['Ea'],df['volume'],marker_list[1],markersize=15,color='k',linewidth=4,label = "V-Ea")
ax6 = ax3.twinx()
ax6.set_xlim((x1,y1))
ax6.set_ylim((-0.2,-2))
# 6x2.set_tick_params(labelsize=23)
ax6.set_xlabel(r'$E_a$ (meV)',font1)
ax6.set_ylabel(r'Anion charge(e)',font1)
ax6.yaxis.label.set_color('blue')
ax6.spines['right'].set_color('blue')
ax6.tick_params(axis='y', colors='blue',labelsize=30)
# # ax2.tick_params(axis='x', labelsize= 30)
# ax6.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax6.set_xticklabels(fontname = 'Times New Roman', size = 23)
a6, = ax6.plot(df['Ea'],-df['a_c'], marker_list[1],markersize=15,color='b', linewidth=4,label='V-CSM')
modified_a_c = [-df['a_c'][0]-0.2, -df['a_c'][1]-0.2,-df['a_c'][2]-0.2,-df['a_c'][3]+0.2,-df['a_c'][4]-0.2,-df['a_c'][5]+0.2,-df['a_c'][6]-0.2,-df['a_c'][7]+0.2]
for i, label in enumerate(elements):
    ax6.text(df['Ea'][i]-10,modified_a_c[i],label,size =30,color='b')
    
    
    
    
ax4 = fig.add_subplot(133)
ax4.set_xlim((x1,y1))
ax4.set_ylim((0,4))
# ax.set_tick_params(labelsize=23)
ax4.set_xlabel(r'$E_a$ (meV)',font1)
ax4.set_ylabel('CSM of octahedral sites',font1)
# ax.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax.set_xticklabels(fontname = 'Times New Roman', size = 23)
# plt.plot(X,Y,label='Relationship plot',linewidth=3.0)
ax4.yaxis.label.set_color('black')
a4, = ax4.plot(df['Ea'],df['csm_o'],marker_list[0],markersize=15,color='k',linewidth=4,label = "V-transition state volume")

ax5 = ax4.twinx()

ax5.set_xlim((x1,y1))
ax5.set_ylim((0,4))
# ax2.set_tick_params(labelsize=23)
ax5.set_xlabel(r'$E_a$ (meV)',font1)
ax5.set_ylabel(r'CSM of tetrahedral sites ',font1)

# ax2.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax2.set_xticklabels(fontname = 'Times New Roman', size = 23)
a5, = ax5.plot(df['Ea'],df['csm_t'], marker_list[0],markersize=15,color='b', linewidth=4,label='V-CSM')

'''setting the axis color'''
ax5.spines['right'].set_color('blue')
ax5.yaxis.label.set_color('blue')
ax5.tick_params(axis='y', colors='blue')

# ax3.set_title(f'$LiMS_2$ M=(Fe, Cr, Sc, V)')
# ax2.set_title(f'$LiMS_2$ M=(Fe, Cr, Sc, V)')
# ax4.set_title(f'$LiMS_2$ M=(Fe, Cr, Sc, V)')
for a in ax,ax2,ax3,ax4,ax5,ax6:
    labels = a.get_xticklabels() + a.get_yticklabels() 
    [label.set_fontname('Times New Roman') for label in labels]
    [label.set_fontsize(30) for label in labels] 
# # l1 = plt.legend([a1,a2],['V-transition state volume','V-CSM'],loc='upper left',prop = {'size':12})
# ax3.legend([a3,a6],["Ea",'V-Anion Charge'],loc='upper left',prop = {'size':20},frameon=False)
# ax2.legend([a1,a2],['IS:','V-Transition sites CSM'],loc='upper left',prop = {'size':20},frameon=False)
# ax4.legend([a4,a5],['V-Initial sites volume','V-Initial sites CSM'],loc='upper left',prop = {'size':20},frameon=False)
# l2 = plt.legend([a3],['V-Ea'],loc='upper right',prop = {'size':12})
# ax2.vlines(Li_X6[element],0,10.0,colors='k',linestyles='dashed')
# ax2.vlines(Li_X6[element2],0,10.0,colors='k',linestyles='dashed')
# ax2.text(7.55,2.5,'$%sS_4$'%(str(element)),fontsize=30,fontname='Times New Roman')

# ax2.text(4.37,5,'$β-%s_3PS_4$'%(str(element)),fontsize=30,fontname='Times New Roman')
# ax2.text(7.5,8,'$%s_2S$'%(str(element)),fontsize=30,fontname='Times New Roman')
# ax.plot(Li_X6[element],30.99,marker='*',color='k',markersize=30)
# # ax.plot(4.37,23.93,marker='*',color='k',markersize=30)
# ax2.plot(Li_X6[element],0.9,marker='*',color='r',markersize=30)
# # ax2.plot(4.37,2.09,marker='*',color='r',markersize=30)
# ax3.plot(Li_X6[element],0.493,marker='*',color='b',markersize=30)
# # ax3.plot(4.37,0.201,marker='*',color='b',markersize=30)
# ax3.text(7.5,0.52,'$%s_2S$'%(str(element)),fontsize=30,fontname='Times New Roman')
# # ax4.hlines(Li_X6[element],x1,y1,colors='k',linestyles='dashed')
# # ax4.text(x1,Li_X6[element],r'$%s_2S$'%(str(element)),fontsize=30,fontname='Times New Roman')
# # ax4.hlines(Li_X6[element2],x1,y1,colors='k',linestyles='dashed')
# # ax4.text(x1,Li_X6[element2],r'$%sS_4$'%(str(element2)),fontsize=30,fontname='Times New Roman')


# ax2.plot(Li_X6[element],0.9,marker='*',color='r',markersize=30)
# # ax2.plot(4.37,2.09,marker='*',color='r',markersize=30)
# ax3.plot(Li_X6[element],0.493,marker='*',color='k',markersize=30)
# ax3.plot(4.37,0.201,marker='*',color='b',markersize=30)
# ax3.text(4.37,0.25,'$β-%s_3PS_4$'%(str(element)),fontsize=30,fontname='Times New Roman')

plt.show()

# %%
len(LMS_cs)
# Out:
# 6

# %%
csm_o = LMS_cs
csm_t = LMS_ci
elements = ['Sc','Ti','V','Cr','Fe','Ni']
# elements.reverse()
volume = LMS_v1
# ea = 
ea = LMS_Ea
vol_o = LMS_voli
vol_t = LMS_vols
# m_v = [15.4833,18.8320,16.0939,20.1575,19.4468]
a_c = LMS_a
df = pd.DataFrame({'elem':elements,'volume':volume,'Ea':ea,'csm_o':csm_o,'csm_t':csm_t,'vol_o':vol_o,'vol_t':vol_t,'a_c':a_c})

# %%
LMS_vols
# Out:
# [31.8962, 31.3438, 31.1828, 30.7726, 30.5792, 29.934]

# %%
# font1 = {'family' : 'Times New Roman',
# 'weight' : 'normal',
# 'size'   : 40}
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(33,10),dpi=300)
# plt.tight_layout()  
tit = 'X=I'
MX6 = 'MS_4'
element = 'Li'
element2 = 'P'
bader_chg_list = [0.72848437,0.9622875,1.2816375,1.58618438]
Li_X6 = {'Cl':22.80,'Br':27.9328,'I':36.4646,'P':4.37,'Li':7.8035}
Li_S = {'P','S','P3S11'}
x1 = -50
y1 = 650
marker_list =  ['o', 'p', '^', '-<','-p','-s','-d']
# ax = fig.add_subplot(111)
# ax.set_xlim((4,8))
# ax.set_ylim((24,30))
# # ax.set_tick_params(labelsize=23)
# ax.set_xlabel(r'$(XS_4)$Volume($A^3$)',font1)
# ax.set_ylabel(r'Transition Volume($A^3$)',font1)
ax = fig.add_subplot(132)
fig.subplots_adjust(wspace =0.5, hspace =0.2)
ax.set_xlim((x1,y1))

ax.set_ylim((28,34))
# ax.set_tick_params(labelsize=23)
ax.set_xlabel(r'$E_a$ (meV)',font1)
ax.set_ylabel('Volume of octahedral sites ($\AA^3$)',font1)

# ax.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax.set_xticklabels(fontname = 'Times New Roman', size = 23)
# plt.plot(X,Y,label='Relationship plot',linewidth=3.0)
ax.yaxis.label.set_color('black')
a1, = ax.plot(df['Ea'],df['vol_t'],marker_list[0],markersize=15,color='k',linewidth=4,label = "V-transition state volume")

ax2 = ax.twinx()

ax2.set_xlim((x1,y1))
ax2.set_ylim((7.4,8.4))
# ax2.set_tick_params(labelsize=23)
ax2.set_xlabel(r'$E_a$ (meV)',font1)
ax2.set_ylabel(r'Volume of tetrahedral sites ($\AA^3$)',font1)

ax2.tick_params(axis='x', labelsize= 30)
a2, = ax2.plot(df['Ea'],df['vol_o'], marker_list[0],markersize=15,color='b', linewidth=4,label='V-CSM')

'''setting the axis color'''
ax2.spines['right'].set_color('blue')
ax2.yaxis.label.set_color('blue')
ax2.tick_params(axis='y', colors='blue')



ax3 = fig.add_subplot(131)
ax3.set_xlim((x1,y1))
ax3.set_ylim((30,50))
# ax.set_tick_params(labelsize=23)
ax3.set_xlabel(r'$E_a$ (meV)',font1)
ax3.set_ylabel('Anion sublattice volume ($\AA^3$)',font1)

# plt.plot(X,Y,label='Relationship plot',linewidth=3.0)
ax3.yaxis.label.set_color('black')
ax3.spines['left'].set_color('black')
ax3.yaxis.label.set_color('black')
ax3.tick_params(axis='y', colors='black',labelsize=20)
a3, = ax3.plot(df['Ea'],df['volume'],marker_list[1],markersize=15,color='k',linewidth=4,label = "V-Ea")
ax6 = ax3.twinx()
ax6.set_xlim((x1,y1))
ax6.set_ylim((0,-2))
# 6x2.set_tick_params(labelsize=23)
ax6.set_xlabel(r'$E_a$ (meV)',font1)
ax6.set_ylabel(r'Anion charge(e)',font1)
ax6.yaxis.label.set_color('blue')
ax6.spines['right'].set_color('blue')
ax6.tick_params(axis='y', colors='blue',labelsize=30)
# # ax2.tick_params(axis='x', labelsize= 30)
# ax6.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax6.set_xticklabels(fontname = 'Times New Roman', size = 23)
a6, = ax6.plot(df['Ea'],-df['a_c'], marker_list[1],markersize=15,color='b', linewidth=4,label='V-CSM')
modified_a = [-df['a_c'][0]+0.3,-df['a_c'][1]+0.3,-df['a_c'][2]+0.3,-df['a_c'][3]+0.3,-df['a_c'][4]+0.3,-df['a_c'][5]-0.3]
for i, label in enumerate(elements):
    ax6.text(df['Ea'][i]-10,modified_a[i],label,size =30,color='b')
    
    
    
    
ax4 = fig.add_subplot(133)
ax4.set_xlim((x1,y1))
ax4.set_ylim((-0.05,4))
# ax.set_tick_params(labelsize=23)
ax4.set_xlabel(r'$E_a$ (meV)',font1)
ax4.set_ylabel('CSM of octahedral sites',font1)
# ax.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax.set_xticklabels(fontname = 'Times New Roman', size = 23)
# plt.plot(X,Y,label='Relationship plot',linewidth=3.0)
ax4.yaxis.label.set_color('black')
a4, = ax4.plot(df['Ea'],df['csm_o'],marker_list[0],markersize=15,color='k',linewidth=4,label = "V-transition state volume")

ax5 = ax4.twinx()

ax5.set_xlim((x1,y1))
ax5.set_ylim((-0.05,4))
# ax2.set_tick_params(labelsize=23)
ax5.set_xlabel(r'$E_a$ (meV)',font1)
ax5.set_ylabel(r'CSM of tetrahedral sites ',font1)

# ax2.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax2.set_xticklabels(fontname = 'Times New Roman', size = 23)
a5, = ax5.plot(df['Ea'],df['csm_t'], marker_list[0],markersize=15,color='b', linewidth=4,label='V-CSM')

'''setting the axis color'''
ax5.spines['right'].set_color('blue')
ax5.yaxis.label.set_color('blue')
ax5.tick_params(axis='y', colors='blue')

# ax3.set_title(f'$LiMS_2$ M=(Fe, Cr, Sc, V)')
# ax2.set_title(f'$LiMS_2$ M=(Fe, Cr, Sc, V)')
# ax4.set_title(f'$LiMS_2$ M=(Fe, Cr, Sc, V)')
for a in ax,ax2,ax3,ax4,ax5,ax6:
    labels = a.get_xticklabels() + a.get_yticklabels() 
    [label.set_fontname('Times New Roman') for label in labels]
    [label.set_fontsize(30) for label in labels] 
# # l1 = plt.legend([a1,a2],['V-transition state volume','V-CSM'],loc='upper left',prop = {'size':12})
# ax3.legend([a3,a6],["Ea",'V-Anion Charge'],loc='upper left',prop = {'size':20},frameon=False)
# ax2.legend([a1,a2],['IS:','V-Transition sites CSM'],loc='upper left',prop = {'size':20},frameon=False)
# ax4.legend([a4,a5],['V-Initial sites volume','V-Initial sites CSM'],loc='upper left',prop = {'size':20},frameon=False)
# l2 = plt.legend([a3],['V-Ea'],loc='upper right',prop = {'size':12})
# ax2.vlines(Li_X6[element],0,10.0,colors='k',linestyles='dashed')
# ax2.vlines(Li_X6[element2],0,10.0,colors='k',linestyles='dashed')
# ax2.text(7.55,2.5,'$%sS_4$'%(str(element)),fontsize=30,fontname='Times New Roman')

# ax2.text(4.37,5,'$β-%s_3PS_4$'%(str(element)),fontsize=30,fontname='Times New Roman')
# ax2.text(7.5,8,'$%s_2S$'%(str(element)),fontsize=30,fontname='Times New Roman')
# ax.plot(Li_X6[element],30.99,marker='*',color='k',markersize=30)
# # ax.plot(4.37,23.93,marker='*',color='k',markersize=30)
# ax2.plot(Li_X6[element],0.9,marker='*',color='r',markersize=30)
# # ax2.plot(4.37,2.09,marker='*',color='r',markersize=30)
# ax3.plot(Li_X6[element],0.493,marker='*',color='b',markersize=30)
# # ax3.plot(4.37,0.201,marker='*',color='b',markersize=30)
# ax3.text(7.5,0.52,'$%s_2S$'%(str(element)),fontsize=30,fontname='Times New Roman')
# # ax4.hlines(Li_X6[element],x1,y1,colors='k',linestyles='dashed')
# # ax4.text(x1,Li_X6[element],r'$%s_2S$'%(str(element)),fontsize=30,fontname='Times New Roman')
# # ax4.hlines(Li_X6[element2],x1,y1,colors='k',linestyles='dashed')
# # ax4.text(x1,Li_X6[element2],r'$%sS_4$'%(str(element2)),fontsize=30,fontname='Times New Roman')


# ax2.plot(Li_X6[element],0.9,marker='*',color='r',markersize=30)
# # ax2.plot(4.37,2.09,marker='*',color='r',markersize=30)
# ax3.plot(Li_X6[element],0.493,marker='*',color='k',markersize=30)
# ax3.plot(4.37,0.201,marker='*',color='b',markersize=30)
# ax3.text(4.37,0.25,'$β-%s_3PS_4$'%(str(element)),fontsize=30,fontname='Times New Roman')

plt.show()

# %%
PLMS_co = [1.144831,0.952658,1.016334,0.912426,0.903831] 
PLMS_ct = [4.725657,3.475794,4.283016,3.732423,2.806455]
elements = ['Co','Cr','Fe','Ti','V']
PLMS_v = [115.257340/4,30.549020,115.64957/4,31.369534,126.961695/4]
ea = [0.298800,0.145000,0.167500,0.176200,0.025900]
PLMS_Ea = [i*1000 for i in ea]
PLMS_volo = [21.6712,22.0975,21.7474,22.1233,22.2524]
PLMS_volt =[6.3614,6.5786,6.3242,6.5535,6.8539]
m_v = [15.4833,18.8320,16.0939,20.1575,19.4468]
PLMS_a = [-0.747,-1.036,-0.846,-1.090,-1.116]
df = pd.DataFrame({'elem':elements,'volume':PLMS_v,'Ea':PLMS_Ea,'csm_o':PLMS_co,'csm_t':PLMS_ct,'vol_o':PLMS_volo,'vol_t':PLMS_volt,'a_c':PLMS_a})

# %%
df['vol_t']
# Out:
# 0    6.3614
# 1    6.5786
# 2    6.3242
# 3    6.5535
# 4    6.8539
# Name: vol_t, dtype: float64

# %%
# font1 = {'family' : 'Times New Roman',
# 'weight' : 'normal',
# 'size'   : 40}
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(33,10),dpi=300)
# plt.tight_layout()  
tit = 'X=I'
MX6 = 'MS_4'
element = 'Li'
element2 = 'P'
bader_chg_list = [0.72848437,0.9622875,1.2816375,1.58618438]
Li_X6 = {'Cl':22.80,'Br':27.9328,'I':36.4646,'P':4.37,'Li':7.8035}
Li_S = {'P','S','P3S11'}
x1 = -50
y1 = 950
marker_list =  ['o', 'p', '-^', '-<','-p','-s','-d']
# ax = fig.add_subplot(111)
# ax.set_xlim((4,8))
# ax.set_ylim((24,30))
# # ax.set_tick_params(labelsize=23)
# ax.set_xlabel(r'$(XS_4)$Volume($A^3$)',font1)
# ax.set_ylabel(r'Transition Volume($A^3$)',font1)
ax = fig.add_subplot(132)
fig.subplots_adjust(wspace =0.5, hspace =0.2)
ax.set_xlim((x1,y1))
ax.set_ylim((20,24))
# ax.set_tick_params(labelsize=23)
ax.set_xlabel(r'$E_a$ (meV)',font1)
ax.set_ylabel('Volume of octahedron sites ($\AA^3$)',font1)

# ax.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax.set_xticklabels(fontname = 'Times New Roman', size = 23)
# plt.plot(X,Y,label='Relationship plot',linewidth=3.0)
ax.yaxis.label.set_color('black')
a1, = ax.plot(df['Ea'],df['vol_o'],marker_list[0],markersize=15,color='k',linewidth=4,label = "V-transition state volume")

ax2 = ax.twinx()

ax2.set_xlim((x1,y1))
ax2.set_ylim((6,7))
# ax2.set_tick_params(labelsize=23)
ax2.set_xlabel(r'$E_a$ (meV)',font1)
ax2.set_ylabel(r'Volume of Tetrahedron sites ($\AA^3$)',font1)

ax2.tick_params(axis='x', labelsize= 30)
a2, = ax2.plot(df['Ea'],df['vol_t'], marker_list[0],markersize=15,color='b', linewidth=4,label='V-CSM')

'''setting the axis color'''
ax2.spines['right'].set_color('blue')
ax2.yaxis.label.set_color('blue')
ax2.tick_params(axis='y', colors='blue')



ax3 = fig.add_subplot(131)
ax3.set_xlim((x1,y1))
ax3.set_ylim((0,50))
# ax.set_tick_params(labelsize=23)
ax3.set_xlabel(r'$E_a$ (meV)',font1)
ax3.set_ylabel('Lattice Volume ($\AA^3$)',font1)

# plt.plot(X,Y,label='Relationship plot',linewidth=3.0)
ax3.yaxis.label.set_color('black')
ax3.spines['left'].set_color('black')
ax3.yaxis.label.set_color('black')
ax3.tick_params(axis='y', colors='black',labelsize=20)
a3, = ax3.plot(df['Ea'],df['volume'],marker_list[1],markersize=15,color='k',linewidth=4,label = "V-Ea")
ax6 = ax3.twinx()
ax6.set_xlim((x1,y1))
ax6.set_ylim((0,-2))
# 6x2.set_tick_params(labelsize=23)
ax6.set_xlabel(r'$E_a$ (meV)',font1)
ax6.set_ylabel(r'Anion Charge(e)',font1)
ax6.yaxis.label.set_color('blue')
ax6.spines['right'].set_color('blue')
ax6.tick_params(axis='y', colors='blue',labelsize=30)
# # ax2.tick_params(axis='x', labelsize= 30)
# ax6.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax6.set_xticklabels(fontname = 'Times New Roman', size = 23)
a6, = ax6.plot(df['Ea'],df['a_c'], marker_list[1],markersize=15,color='b', linewidth=4,label='V-CSM')
# modified_a = [-df['a_c'][0]+0.1,-df['a_c'][1]+0.1,-df['a_c'][2]+0.1,-df['a_c'][3]+0.1,-df['a_c'][4]+0.1]
# for i, label in enumerate(elements):
#     ax6.text(df['Ea'][i]-10,modified_a[i],label,size =30,color='b')
    
    
    
    
ax4 = fig.add_subplot(133)
ax4.set_xlim((x1,y1))
ax4.set_ylim((0,5))
# ax.set_tick_params(labelsize=23)
ax4.set_xlabel(r'$E_a$ (meV)',font1)
ax4.set_ylabel('CSM of octahedron sites',font1)
# ax.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax.set_xticklabels(fontname = 'Times New Roman', size = 23)
# plt.plot(X,Y,label='Relationship plot',linewidth=3.0)
ax4.yaxis.label.set_color('black')
a4, = ax4.plot(df['Ea'],df['csm_o'],marker_list[0],markersize=15,color='k',linewidth=4,label = "V-transition state volume")

ax5 = ax4.twinx()

ax5.set_xlim((x1,y1))
ax5.set_ylim((0,5))
# ax2.set_tick_params(labelsize=23)
ax5.set_xlabel(r'$E_a$ (meV)',font1)
ax5.set_ylabel(r'CSM of tetrahedron sites ',font1)

# ax2.set_yticklabels(fontname = 'Times New Roman', size = 23)
# ax2.set_xticklabels(fontname = 'Times New Roman', size = 23)
a5, = ax5.plot(df['Ea'],df['csm_t'], marker_list[0],markersize=15,color='b', linewidth=4,label='V-CSM')

'''setting the axis color'''
ax5.spines['right'].set_color('blue')
ax5.yaxis.label.set_color('blue')
ax5.tick_params(axis='y', colors='blue')

# ax3.set_title(f'$LiMS_2$ M=(Fe, Cr, Sc, V)')
# ax2.set_title(f'$LiMS_2$ M=(Fe, Cr, Sc, V)')
# ax4.set_title(f'$LiMS_2$ M=(Fe, Cr, Sc, V)')
for a in ax,ax2,ax3,ax4,ax5,ax6:
    labels = a.get_xticklabels() + a.get_yticklabels() 
    [label.set_fontname('Times New Roman') for label in labels]
    [label.set_fontsize(30) for label in labels] 
# # l1 = plt.legend([a1,a2],['V-transition state volume','V-CSM'],loc='upper left',prop = {'size':12})
# ax3.legend([a3,a6],["Ea",'V-Anion Charge'],loc='upper left',prop = {'size':20},frameon=False)
# ax2.legend([a1,a2],['IS:','V-Transition sites CSM'],loc='upper left',prop = {'size':20},frameon=False)
# ax4.legend([a4,a5],['V-Initial sites volume','V-Initial sites CSM'],loc='upper left',prop = {'size':20},frameon=False)
# l2 = plt.legend([a3],['V-Ea'],loc='upper right',prop = {'size':12})
# ax2.vlines(Li_X6[element],0,10.0,colors='k',linestyles='dashed')
# ax2.vlines(Li_X6[element2],0,10.0,colors='k',linestyles='dashed')
# ax2.text(7.55,2.5,'$%sS_4$'%(str(element)),fontsize=30,fontname='Times New Roman')

# ax2.text(4.37,5,'$β-%s_3PS_4$'%(str(element)),fontsize=30,fontname='Times New Roman')
# ax2.text(7.5,8,'$%s_2S$'%(str(element)),fontsize=30,fontname='Times New Roman')
# ax.plot(Li_X6[element],30.99,marker='*',color='k',markersize=30)
# # ax.plot(4.37,23.93,marker='*',color='k',markersize=30)
# ax2.plot(Li_X6[element],0.9,marker='*',color='r',markersize=30)
# # ax2.plot(4.37,2.09,marker='*',color='r',markersize=30)
# ax3.plot(Li_X6[element],0.493,marker='*',color='b',markersize=30)
# # ax3.plot(4.37,0.201,marker='*',color='b',markersize=30)
# ax3.text(7.5,0.52,'$%s_2S$'%(str(element)),fontsize=30,fontname='Times New Roman')
# # ax4.hlines(Li_X6[element],x1,y1,colors='k',linestyles='dashed')
# # ax4.text(x1,Li_X6[element],r'$%s_2S$'%(str(element)),fontsize=30,fontname='Times New Roman')
# # ax4.hlines(Li_X6[element2],x1,y1,colors='k',linestyles='dashed')
# # ax4.text(x1,Li_X6[element2],r'$%sS_4$'%(str(element2)),fontsize=30,fontname='Times New Roman')


# ax2.plot(Li_X6[element],0.9,marker='*',color='r',markersize=30)
# # ax2.plot(4.37,2.09,marker='*',color='r',markersize=30)
# ax3.plot(Li_X6[element],0.493,marker='*',color='k',markersize=30)
# ax3.plot(4.37,0.201,marker='*',color='b',markersize=30)
# ax3.text(4.37,0.25,'$β-%s_3PS_4$'%(str(element)),fontsize=30,fontname='Times New Roman')

plt.show()
